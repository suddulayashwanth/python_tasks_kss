# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:300%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             text-align: center;"><u><b>CUSTOMER CHURN PREDICTION</b></u>
# </div>

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>IMPORT NEEDED LIBRARIES </b>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>DATASET LOADING ... </b>
# </div>

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>DISPLAY A SAMPLE ... </b>
# </div>

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1785  1568-LJSZU    Male              0     Yes        Yes      68
# 5329  2894-QOJRX  Female              0     Yes         No      25
# 1417  5651-WYIPH  Female              1      No         No      18
# 6501  4753-PADAS  Female              0     Yes         No      67
# 2366  1846-XWOQN  Female              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1785          Yes               Yes             DSL            Yes  ...
# 5329           No  No phone service             DSL             No  ...
# 1417          Yes                No             DSL             No  ...
# 6501          Yes               Yes     Fiber optic             No  ...
# 2366          Yes                No     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 1785              Yes         Yes         Yes             Yes        Two year
# 5329               No          No         Yes              No  Month-to-month
# 1417               No          No          No              No  Month-to-month
# 6501              Yes          No         Yes             Yes        One year
# 2366               No          No          No              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 1785              Yes    Credit card (automatic)          92.20       6392.85
# 5329              Yes  Bank transfer (automatic)          34.00           853
# 1417              Yes    Credit card (automatic)          49.85        865.75
# 6501              Yes  Bank transfer (automatic)         105.70       6816.95
# 2366              Yes           Electronic check          70.15         70.15
#
#      Churn
# 1785    No
# 5329   Yes
# 1417    No
# 6501    No
# 2366   Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>DATASET GENERAL INFORMATION </b>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>DATA PRE-PROCESSING ... </b>
# </div>

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>CustomerID </b>
# </div>

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
#
#   Drop customerID column as it is useless for the Model

# %%
df.drop('customerID',axis='columns',inplace=True)

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>Gender </b>
# </div>

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

counts = df["gender"].value_counts()
explode = (0, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Males Vs Females')
plt.xlabel('Gender', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Counts', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
#
#  Convert 'Male' to 0 and 'Female' to 1

# %%
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1})

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>Partner </b>
# </div>

# %%
df['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

counts = df["Partner"].value_counts()
explode = (0, 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Yes Vs No')
plt.xlabel('Status', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Count', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
#
#  Convert 'No' to 0 and 'Yes' to 1

# %%
df['Partner'] = df['Partner'].map({'No': 0, 'Yes': 1})

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b> Dependents </b>
# </div>

# %%
df['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

ax = df["Dependents"].value_counts().plot(kind = 'bar', color = colors[:2], rot = 0)
ax.set_xticklabels(('Yes', 'No'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('Status', weight = "bold", color = "#D71313", fontsize = 14)
plt.ylabel('Count', weight = "bold", color = "#D71313", fontsize = 14);

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
#
#  Convert 'No' to 0 and 'Yes' to 1

# %%
df['Dependents'] = df['Dependents'].map({'No': 0, 'Yes': 1})

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>PhoneService </b>
# </div>

# %%
df['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
colors = ["#34eb6b" , "#0099ff"]

plt.figure(figsize = (20, 6))

ax = df["PhoneService"].value_counts().plot(kind = 'bar', color = colors[:2], rot = 0)
ax.set_xticklabels(('Yes', 'No'))

for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x() + 0.25, p.get_height() + 1), ha = 'center', va = 'bottom', color = 'black')
    ax.tick_params(axis = 'both', labelsize = 15)

plt.xlabel('Status', weight = "bold", color = "#D71313", fontsize = 14)
plt.ylabel('Count', weight = "bold", color = "#D71313", fontsize = 14);

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
#
#  Convert 'No' to 0 and 'Yes' to 1

# %%
df['PhoneService'] = df['PhoneService'].map({'No': 0, 'Yes': 1})

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>MultipleLines </b>
# </div>

# %%
df['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
colors = ["#2B299B" , "#3B74C9" , "#85DFE3"]

plt.figure(figsize = (20, 6))

counts = df["MultipleLines"].value_counts()
explode = (0, 0.1  , 0.1)

counts.plot(kind = 'pie', fontsize = 12, colors = colors, explode = explode, autopct = '%.1f%%')
plt.title('Status')
plt.xlabel('Status', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.ylabel('Count', weight = "bold", color = "#2F0F5D", fontsize = 14, labelpad = 20)
plt.legend(labels = counts.index, loc = "best")
plt.show()

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
#
#  Convert 'No phone service' to 0 &  Convert 'No' to 0 and 'Yes' to 1

# %%
mapping_dict = {'No phone service': 0, 'No': 0, 'Yes': 1}

df['MultipleLines'] = df['MultipleLines'].map(mapping_dict)

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>[InternetService, Contract, PaymentMethod] </b>
# </div>

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>Using sklearn OneHotEncoder </b>
# </div>

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df.InternetService = le.fit_transform(df.InternetService)

# %%
df.Contract = le.fit_transform(df.Contract)

# %%
df.PaymentMethod = le.fit_transform(df.PaymentMethod)

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>DISPLAT ANOTHER SAMPLE .. </b>
# </div>

# %%
df.sample(4)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 6869       1              0        1           1      45             1
# 1305       1              0        0           0      28             1
# 565        0              0        1           1      71             1
# 1565       1              0        0           0      55             1
#
#       MultipleLines  InternetService OnlineSecurity OnlineBackup  \
# 6869              0                0             No          Yes
# 1305              0                0             No           No
# 565               0                0            Yes           No
# 1565              0                1             No          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 6869               No         Yes          No              No         1
# 1305              Yes          No         Yes              No         0
# 565               Yes         Yes          No             Yes         2
# 1565              Yes          No          No              No         0
#
#      PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges Churn
# 6869              Yes              1           54.15       2319.8   Yes
# 1305              Yes              0           59.55      1646.45    No
# 565               Yes              1           70.85       4973.4    No
# 1565              Yes              2           81.55       4509.5    No

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
#
# To avoid redundancy, One function to pre-process them all

# %%
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)

# %%
yes_no_columns = ['Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','Churn']
for col in yes_no_columns:
    df[col].replace({'Yes': 1,'No': 0},inplace=True)

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>TotalCharges</b>
# </div>

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
# Check the Null Values ...

# %%
pd.to_numeric(df.TotalCharges,errors='coerce').isnull().sum()
# Out:
# np.int64(11)

# %%
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 488        1              0        1           1       0             0
# 753        0              0        0           1       0             1
# 936        1              0        1           1       0             1
# 1082       0              0        1           1       0             1
# 1340       1              0        1           1       0             0
# 3331       0              0        1           1       0             1
# 3826       0              0        1           1       0             1
# 4380       1              0        1           1       0             1
# 5218       0              0        1           1       0             1
# 6670       1              0        1           1       0             1
# 6754       0              0        0           1       0             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 488               0                0               1             0
# 753               0                2               0             0
# 936               0                0               1             1
# 1082              1                2               0             0
# 1340              0                0               1             1
# 3331              0                2               0             0
# 3826              1                2               0             0
# 4380              0                2               0             0
# 5218              0                2               0             0
# 6670              1                0               0             1
# 6754              1                0               1             1
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 488                  1            1            1                0         2
# 753                  0            0            0                0         2
# 936                  1            0            1                1         2
# 1082                 0            0            0                0         2
# 1340                 1            1            1                0         2
# 3331                 0            0            0                0         2
# 3826                 0            0            0                0         2
# 4380                 0            0            0                0         2
# 5218                 0            0            0                0         1
# 6670                 1            1            1                0         2
# 6754                 0            1            0                0         2
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges TotalCharges  Churn
# 488                  1              0           52.55                   0
# 753                  0              3           20.25                   0
# 936                  0              3           80.85                   0
# 1082                 0              3           25.75                   0
# 1340                 0              1           56.05                   0
# 3331                 0              3           19.85                   0
# 3826                 0              3           25.35                   0
# 4380                 0              3           20.00                   0
# 5218                 1              3           19.70                   0
# 6670                 0              3           73.35                   0
# 6754                 1              0           61.90                   0

# %%
df.shape
# Out:
# (7043, 20)

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#e3e3e3
#               ;font-family:Times New Roman;
#               font-size:110%;padding:10px'>
#
# Remove rows with space in TotalCharges

# %%
df = df[df.TotalCharges!=' ']
df.shape
# Out:
# (7032, 20)

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>MinMaxScaler</b>
# </div>

# %%
cols_to_scale = ['tenure','MonthlyCharges','TotalCharges']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
df[cols_to_scale ].sample(5)
# Out:
#         tenure  MonthlyCharges  TotalCharges
# 2572  0.985915        0.067164      0.200115
# 6251  0.000000        0.009950      0.000052
# 6252  0.690141        0.210945      0.231081
# 571   0.647887        0.411443      0.315624
# 4082  0.676056        0.657711      0.466253

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>DATASET FINAL SUMMARY </b>
# </div>

# %%
def summary(df):
    summary_df = pd.DataFrame(df.dtypes, columns=['dtypes'])
    summary_df['missing#'] = df.isna().sum()
    summary_df['missing%'] = (df.isna().sum())/len(df)
    summary_df['unique'] = df.nunique().values
    summary_df['count'] = df.count().values
    return summary_df

summary(df).style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_babdc_row0_col1, #T_babdc_row0_col2, #T_babdc_row0_col3, #T_babdc_row0_col4, #T_babdc_row1_col1, #T_babdc_row1_col2, #T_babdc_row1_col3, #T_babdc_row1_col4, #T_babdc_row2_col1, #T_babdc_row2_col2, #T_babdc_row2_col3, #T_babdc_row2_col4, #T_babdc_row3_col1, #T_babdc_row3_col2, #T_babdc_row3_col3, #T_babdc_row3_col4, #T_babdc_row4_col1, #T_babdc_row4_col2, #T_babdc_row4_col4, #T_babdc_row5_col1, #T_babdc_row5_col2, #T_babdc_row5_col3, #T_babdc_row5_col4, #T_babdc_row6_col1, #T_babdc_row6_col2, #T_babdc_row6_col3, #T_babdc_row6_col4, #T_babdc_row7_col1, #T_babdc_row7_col2, #T_babdc_row7_col3, #T_babdc_row7_col4, #T_babdc_row8_col1, #T_babdc_row8_col2, #T_babdc_row8_col3, #T_babdc_row8_col4, #T_babdc_row9_col1, #T_babdc_row9_col2, #T_babdc_row9_col3, #T_babdc_row9_col4, #T_babdc_row10_col1, #T_babdc_row10_col2, #T_babdc_row10_col3, #T_babdc_row10_col4, #T_babdc_row11_col1, #T_babdc_row11_col2, #T_babdc_row11_col3, #T_babdc_row11_col4, #T_babdc_row12_col1, #T_babdc_row12_col2, #T_babdc_row12_col3, #T_babdc_row12_col4, #T_babdc_row13_col1, #T_babdc_row13_col2, #T_babdc_row13_col3, #T_babdc_row13_col4, #T_babdc_row14_col1, #T_babdc_row14_col2, #T_babdc_row14_col3, #T_babdc_row14_col4, #T_babdc_row15_col1, #T_babdc_row15_col2, #T_babdc_row15_col3, #T_babdc_row15_col4, #T_babdc_row16_col1, #T_babdc_row16_col2, #T_babdc_row16_col3, #T_babdc_row16_col4, #T_babdc_row17_col1, #T_babdc_row17_col2, #T_babdc_row17_col4, #T_babdc_row18_col1, #T_babdc_row18_col2, #T_babdc_row18_col4, #T_babdc_row19_col1, #T_babdc_row19_col2, #T_babdc_row19_col3, #T_babdc_row19_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_babdc_row4_col3 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_babdc_row17_col3 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_babdc_row18_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_babdc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_babdc_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_babdc_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_babdc_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_babdc_level0_col3" class="col_heading level0 col3" >unique</th>
#       <th id="T_babdc_level0_col4" class="col_heading level0 col4" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_babdc_level0_row0" class="row_heading level0 row0" >gender</th>
#       <td id="T_babdc_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_babdc_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_babdc_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_babdc_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_babdc_row0_col4" class="data row0 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row1" class="row_heading level0 row1" >SeniorCitizen</th>
#       <td id="T_babdc_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_babdc_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_babdc_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_babdc_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_babdc_row1_col4" class="data row1 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row2" class="row_heading level0 row2" >Partner</th>
#       <td id="T_babdc_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_babdc_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_babdc_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_babdc_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_babdc_row2_col4" class="data row2 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row3" class="row_heading level0 row3" >Dependents</th>
#       <td id="T_babdc_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_babdc_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_babdc_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_babdc_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_babdc_row3_col4" class="data row3 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row4" class="row_heading level0 row4" >tenure</th>
#       <td id="T_babdc_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_babdc_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_babdc_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_babdc_row4_col3" class="data row4 col3" >72</td>
#       <td id="T_babdc_row4_col4" class="data row4 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row5" class="row_heading level0 row5" >PhoneService</th>
#       <td id="T_babdc_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_babdc_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_babdc_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_babdc_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_babdc_row5_col4" class="data row5 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row6" class="row_heading level0 row6" >MultipleLines</th>
#       <td id="T_babdc_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_babdc_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_babdc_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_babdc_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_babdc_row6_col4" class="data row6 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row7" class="row_heading level0 row7" >InternetService</th>
#       <td id="T_babdc_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_babdc_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_babdc_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_babdc_row7_col3" class="data row7 col3" >3</td>
#       <td id="T_babdc_row7_col4" class="data row7 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row8" class="row_heading level0 row8" >OnlineSecurity</th>
#       <td id="T_babdc_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_babdc_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_babdc_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_babdc_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_babdc_row8_col4" class="data row8 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row9" class="row_heading level0 row9" >OnlineBackup</th>
#       <td id="T_babdc_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_babdc_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_babdc_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_babdc_row9_col3" class="data row9 col3" >2</td>
#       <td id="T_babdc_row9_col4" class="data row9 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row10" class="row_heading level0 row10" >DeviceProtection</th>
#       <td id="T_babdc_row10_col0" class="data row10 col0" >int64</td>
#       <td id="T_babdc_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_babdc_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_babdc_row10_col3" class="data row10 col3" >2</td>
#       <td id="T_babdc_row10_col4" class="data row10 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row11" class="row_heading level0 row11" >TechSupport</th>
#       <td id="T_babdc_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_babdc_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_babdc_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_babdc_row11_col3" class="data row11 col3" >2</td>
#       <td id="T_babdc_row11_col4" class="data row11 col4" >7032</td>
#     </tr>
#     <tr>
#       <th id="T_babdc_level0_row12" class="row_heading level0 row12" >StreamingTV</th>
#       <td id="T_babdc_row12_col0" class="data row12 col0" >int64</td>
#       <td id="T_babdc_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_babdc_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_ba

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>Determine Predictor & Target</b>
# </div>

# %%
X = df.drop('Churn',axis='columns')
y = df['Churn']

# %%
X.sample(3)
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 113        1              1        1           0  0.507042             1
# 6572       0              0        1           0  0.943662             1
# 1224       0              0        1           1  0.000000             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 113               1                1               0             0
# 6572              1                0               1             1
# 1224              0                0               0             0
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 113                  0            0            0                0         0
# 6572                 1            1            1                1         2
# 1224                 0            0            0                0         0
#
#       PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges
# 113                  1              2        0.579602      0.328796
# 6572                 1              1        0.721891      0.725138
# 1224                 1              3        0.274627      0.003121

# %%
y.sample(3)
# Out:
# 6217    0
# 6385    1
# 5317    1
# Name: Churn, dtype: int64

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>DATA SPLIT ...</b>
# </div>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (5625, 19)

# %%
X_test.shape
# Out:
# (1407, 19)

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>BUILDING THE ANN MODEL </b>
# </div>

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(15, input_shape=(19,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7362 - loss: 0.5205
# Epoch 2/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7692 - loss: 0.4523
# Epoch 3/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7879 - loss: 0.4362
# Epoch 4/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7922 - loss: 0.4298
# Epoch 5/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7940 - loss: 0.4248
# Epoch 6/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7948 - loss: 0.4223
# Epoch 7/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7975 - loss: 0.4192
# Epoch 8/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7988 - loss: 0.4172
# Epoch 9/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8023 - loss: 0.4151
# Epoch 10/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8039 - loss: 0.4132
# Epoch 11/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8021 - loss: 0.4123
# Epoch 12/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8057 - loss: 0.4107
# Epoch 13/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8053 - loss: 0.4098
# Epoch 14/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8064 - loss: 0.4090
# Epoch 15/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8096 - loss: 0.4077
# Epoch 16/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8069 - loss: 0.4071
# Epoch 17/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8089 - loss: 0.4065
# Epoch 18/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8130 - loss: 0.4049
# Epoch 19/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8096 - loss: 0.4047
# Epoch 20/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8087 - loss: 0.4044
# Epoch 21/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8119 - loss: 0.4041
# Epoch 22/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8123 - loss: 0.4028
# Epoch 23/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8080 - loss: 0.4030
# Epoch 24/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8094 - loss: 0.4014
# Epoch 25/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8121 - loss: 0.3999
# Epoch 26/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8128 - loss: 0.4003
# Epoch 27/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8135 - loss: 0.3993
# Epoch 28/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8112 - loss: 0.3986
# Epoch 29/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8151 - loss: 0.3996
# Epoch 30/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8176 - loss: 0.3971
# Epoch 31/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8121 - loss: 0.3977
# Epoch 32/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8140 - loss: 0.3977
# Epoch 33/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8137 - loss: 0.3964
# Epoch 34/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8140 - loss: 0.3952
# Epoch 35/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8135 - loss: 0.3953
# Epoch 36/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8153 - loss: 0.3950
# Epoch 37/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8164 - loss: 0.3960
# Epoch 38/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8139 - loss: 0.3941
# Epoch 39/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8178 - loss: 0.3949
# Epoch 40/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8149 - loss: 0.3935
# Epoch 41/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8144 - loss: 0.3938
# Epoch 42/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8148 - loss: 0.3933
# Epoch 43/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8176 - loss: 0.3924
# Epoch 44/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8164 - loss: 0.3924
# Epoch 45/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8142 - loss: 0.3924
# Epoch 46/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8156 - loss: 0.3919
# Epoch 47/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8158 - loss: 0.3912
# Epoch 48/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8187 - loss: 0.3917
# Epoch 49/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8190 - loss: 0.3914
# Epoch 50/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8167 - loss: 0.3901
# Epoch 51/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8162 - loss: 0.3900
# Epoch 52/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8174 - loss: 0.3903
# Epoch 53/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8185 - loss: 0.3903
# Epoch 54/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8192 - loss: 0.3887
# Epoch 55/100
# 176/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8180 - loss: 0.3890
# Epoch 56/100
# 112/176 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8190 - loss: 0.3989

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>MODEL EVALUATION </b>
# </div>

# %%
model.evaluate(X_test, y_test)

# %% [markdown]
# <div style="padding:10px;
#             color:#30efe0;
#             background-color:#000000;
#             margin:50px;
#             font-size:130%;
#             display:fill;
#             border-radius:10px;
#             border-style: ridge;
#             border-color: #9fc5e8;
#             overflow:hidden;
#             font-weight:400;
#             "><b>MODEL METRICS </b>
# </div>

# %%
from sklearn.metrics import confusion_matrix , classification_report

# %%
yp = model.predict(X_test)

y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
print(classification_report(y_test,y_pred))

# %%
report = classification_report(y_test, y_pred, output_dict=True)
rep = pd.DataFrame(report).transpose()

# Create a heatmap of the classification report
plt.figure(figsize=(10, 6))
sns.heatmap(df.iloc[:-1, :4], annot=True, cmap='Blues')
plt.title('Classification Report')
plt.show()

# %%
# Extract metrics for each class
classes = [str(key) for key in range(len(report) - 3)]  # Extract class labels
precision = [report[key]['precision'] for key in classes]
recall = [report[key]['recall'] for key in classes]
f1_score = [report[key]['f1-score'] for key in classes]

# %%
# Plotting the metrics using a bar chart
plt.figure(figsize=(12, 6))
barWidth = 0.25
r1 = range(len(classes))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

plt.bar(r1, precision, color='#4b0082', width=barWidth, edgecolor='grey', label='Precision')
plt.bar(r2, recall, color='#f0f8ff', width=barWidth, edgecolor='grey', label='Recall')
plt.bar(r3, f1_score, color='#ff7f50', width=barWidth, edgecolor='grey', label='F1-score')

plt.xlabel('Class', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(classes))], classes)
plt.legend()
plt.title("Classification Report Metrics")
plt.show()

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred)

plt.figure(figsize = (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
